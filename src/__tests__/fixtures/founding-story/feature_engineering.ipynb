# %% [markdown]
# # Feature Engineering
#
# This notebook is the one that silently broke in the founding story.
# It hadn't been opened in days when the upstream `users.email` rename happened.

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://localhost/app')

# %%
users_df = pd.read_sql('SELECT id, email, name FROM users', engine)
users_df.head()

# %%
features = users_df.merge(orders_df, left_on='email', right_on='customer_email', how='left')
features.to_parquet('/tmp/features.parquet')
